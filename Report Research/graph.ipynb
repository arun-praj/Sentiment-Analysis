# %%
import numpy as np
import matplotlib.pyplot as plt

ind = np.arange(6)  # the x locations for the groups
width = 0.12  # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

rects1 = ax.bar(ind+width*0, (89,89.5,91.4,88.1,0,0), width)
rects2 = ax.bar(ind+width*1, (88,88.2,89.4,86.9,0,0), width)
rects3 = ax.bar(ind+width*2, (86,86.4,86.4,86.4,0,0), width)
rects4 = ax.bar(ind+width*3, (85,84.9,84.3,85.6,0,0), width)
rects5 = ax.bar(ind+width*4, (84,83.6,81.6,86.2,0,0), width)
rects6 = ax.bar(ind+width*5, (78,79.1,84.2,74.5,0,0), width)
rects7 = ax.bar(ind+width*6, (76,74.9,72.6,77.3,0,0), width)
rects8 = ax.bar(ind+width*7, (72,71.7,71.1,71.9,0,0), width)

ax.set_ylabel('Percentage')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('Accuracy', 'F1 Score', 'Recall','Precision','','') )
algo = ('Logestic','SVC','Multinomial NB','Random Forest','Bernoulli NB','KNN','Gaussain NB','Decision Tree')
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0],rects5[0],rects6[0],rects7[0],rects8[0]), algo )
plt.show()
